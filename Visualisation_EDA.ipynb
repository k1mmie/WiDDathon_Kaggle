# %%
import seaborn as sns
import pandas as pd
import numpy as np
import pandas_profiling
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
wd = '/WIDDatathon/'
f1 = '/WIDDatathon/train.csv'
f2 = 'WIDDatathon/test.csv'

# %%
df = pd.read_csv(f1)

# %%
miss = df.isnull().sum()/len(df)*100
pd.DataFrame(miss).to_csv('missingvalues.csv')

# %%
#Have you ever used your Microfinance Institution account to do the following?
IFI10 = ['IFI10_1','IFI10_2','IFI10_3','IFI10_4','IFI10_5','IFI10_6','IFI10_7','IFI10_8','IFI10_9','IFI10_10','IFI10_11','IFI10_12','IFI10_13','IFI10_14','IFI10_15',\
         'IFI10_16','IFI10_17','IFI10_18','IFI10_19','IFI10_20','IFI10_21','IFI10_22','IFI10_23','is_female']
df_IFI10 = df[IFI10]
#df_IFI10.isnull().sum()/len(df_IFI10)*100

# %%
df_IFI10.replace(inplace=True,to_replace=2,value=0)

# %%
#make sure is_female is removed
IFI10 = df_IFI10.sum(axis=1,min_count=1)

# %%
fig, axx =plt.subplots(figsize=(30,20),ncols=5,nrows=5)
sns.countplot(x="IFI10_1",hue="is_female",data=df_IFI10,ax=axx[0][0]).title.set_text('IFI10_1 Deposit money')
sns.countplot(x="IFI10_2",hue="is_female",data=df_IFI10,ax=axx[0][1]).title.set_text('IFI10_2 Withdraw money')
sns.countplot(x="IFI10_3",hue="is_female",data=df_IFI10,ax=axx[0][2]).title.set_text('IFI10_3 Buy airtime top-ups, pay mobile phone bill')
sns.countplot(x="IFI10_4",hue="is_female",data=df_IFI10,ax=axx[0][3]).title.set_text('IFI10_4 Pay a school fee')
sns.countplot(x="IFI10_5",hue="is_female",data=df_IFI10,ax=axx[0][4]).title.set_text('IFI10_5 Pay a medical bill')
sns.countplot(x="IFI10_6",hue="is_female",data=df_IFI10,ax=axx[1][0]).title.set_text('IFI10_6 Pay a utility bill')
sns.countplot(x="IFI10_7",hue="is_female",data=df_IFI10,ax=axx[1][1]).title.set_text('IFI10_7 Pay rent')
sns.countplot(x="IFI10_8",hue="is_female",data=df_IFI10,ax=axx[1][2]).title.set_text('IFI10_8 Pay a government bill, including tax, fine or fee')
sns.countplot(x="IFI10_9",hue="is_female",data=df_IFI10,ax=axx[1][3]).title.set_text('IFI10_9 Send money to family')
sns.countplot(x="IFI10_10",hue="is_female",data=df_IFI10,ax=axx[1][4]).title.set_text('IFI10_10 Receive money')
sns.countplot(x="IFI10_11",hue="is_female",data=df_IFI10,ax=axx[2][0]).title.set_text('IFI10_11 Receive welfare')
sns.countplot(x="IFI10_12",hue="is_female",data=df_IFI10,ax=axx[2][1]).title.set_text('IFI10_12 Receive wages')
sns.countplot(x="IFI10_13",hue="is_female",data=df_IFI10,ax=axx[2][2]).title.set_text('IFI10_13 Pay for large acquisitions')
sns.countplot(x="IFI10_14",hue="is_female",data=df_IFI10,ax=axx[2][3]).title.set_text('IFI10_14 Make insurance-related payments')
sns.countplot(x="IFI10_15",hue="is_female",data=df_IFI10,ax=axx[2][4]).title.set_text('IFI10_15 Take a loan')
sns.countplot(x="IFI10_16",hue="is_female",data=df_IFI10,ax=axx[3][0]).title.set_text('IFI10_16 Save money')
sns.countplot(x="IFI10_17",hue="is_female",data=df_IFI10,ax=axx[3][1]).title.set_text('IFI10_17 Set aside money for pension')
sns.countplot(x="IFI10_18",hue="is_female",data=df_IFI10,ax=axx[3][2]).title.set_text('IFI10_18 Set money aside')
sns.countplot(x="IFI10_19",hue="is_female",data=df_IFI10,ax=axx[3][3]).title.set_text('IFI10_19 Make an investment')
sns.countplot(x="IFI10_20",hue="is_female",data=df_IFI10,ax=axx[3][4]).title.set_text('IFI10_20 Pay for goods or services')
sns.countplot(x="IFI10_21",hue="is_female",data=df_IFI10,ax=axx[4][0]).title.set_text('IFI10_21 Transfer money between your account')
sns.countplot(x="IFI10_22",hue="is_female",data=df_IFI10,ax=axx[4][1]).title.set_text('IFI10_22 Pay money to or receive money from your savings')
sns.countplot(x="IFI10_23",hue="is_female",data=df_IFI10,ax=axx[4][2]).title.set_text('IFI10_23 Account maintenance')

for ax in axx.flat:
    ax.set(xlabel='')

# %%
#Have you ever used your post office account to do the following?
IFI11 = ['IFI11_1',	'IFI11_2',	'IFI11_3',	'IFI11_4',	'IFI11_5',	'IFI11_6',	'IFI11_7',	'IFI11_8',	'IFI11_9',	'IFI11_10',	'IFI11_11',	'IFI11_12',\
         'IFI11_13',	'IFI11_14',	'IFI11_15',	'IFI11_16',	'IFI11_17',	'IFI11_18',	'IFI11_19',	'IFI11_20',	'IFI11_21',	'IFI11_22',	'IFI11_23','is_female']
df_IFI11 = df[IFI11]
#df_IFI11.isnull().sum()/len(df)*100

# %%
df_IFI11.replace(inplace=True,to_replace=2,value=0)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
IFI11 = df_IFI11.sum(axis=1,min_count=1)

# %%
fig, axx =plt.subplots(figsize=(30,20),ncols=5,nrows=5)
sns.countplot(x="IFI11_1",hue="is_female",data=df_IFI11,ax=axx[0][0]).title.set_text('IFI11_1 Deposit money')
sns.countplot(x="IFI11_2",hue="is_female",data=df_IFI11,ax=axx[0][1]).title.set_text('IFI11_2 Withdraw money')
sns.countplot(x="IFI11_3",hue="is_female",data=df_IFI11,ax=axx[0][2]).title.set_text('IFI11_3 Buy airtime top-ups, pay mobile phone bill')
sns.countplot(x="IFI11_4",hue="is_female",data=df_IFI11,ax=axx[0][3]).title.set_text('IFI11_4 Pay a school fee')
sns.countplot(x="IFI11_5",hue="is_female",data=df_IFI11,ax=axx[0][4]).title.set_text('IFI11_5 Pay a medical bill')
sns.countplot(x="IFI11_6",hue="is_female",data=df_IFI11,ax=axx[1][0]).title.set_text('IFI11_6 Pay a utility bill')
sns.countplot(x="IFI11_7",hue="is_female",data=df_IFI11,ax=axx[1][1]).title.set_text('IFI11_7 Pay rent')
sns.countplot(x="IFI11_8",hue="is_female",data=df_IFI11,ax=axx[1][2]).title.set_text('IFI11_8 Pay a government bill, including tax, fine or fee')
sns.countplot(x="IFI11_9",hue="is_female",data=df_IFI11,ax=axx[1][3]).title.set_text('IFI11_9 Send money to family')
sns.countplot(x="IFI11_10",hue="is_female",data=df_IFI11,ax=axx[1][4]).title.set_text('IFI11_10 Receive money')
sns.countplot(x="IFI11_11",hue="is_female",data=df_IFI11,ax=axx[2][0]).title.set_text('IFI11_11 Receive welfare')
sns.countplot(x="IFI11_12",hue="is_female",data=df_IFI11,ax=axx[2][1]).title.set_text('IFI11_12 Receive wages')
sns.countplot(x="IFI11_13",hue="is_female",data=df_IFI11,ax=axx[2][2]).title.set_text('IFI11_13 Pay for large acquisitions')
sns.countplot(x="IFI11_14",hue="is_female",data=df_IFI11,ax=axx[2][3]).title.set_text('IFI11_14 Make insurance-related payments')
sns.countplot(x="IFI11_15",hue="is_female",data=df_IFI11,ax=axx[2][4]).title.set_text('IFI11_15 Take a loan')
sns.countplot(x="IFI11_16",hue="is_female",data=df_IFI11,ax=axx[3][0]).title.set_text('IFI11_16 Save money')
sns.countplot(x="IFI11_17",hue="is_female",data=df_IFI11,ax=axx[3][1]).title.set_text('IFI11_17 Set aside money for pension')
sns.countplot(x="IFI11_18",hue="is_female",data=df_IFI11,ax=axx[3][2]).title.set_text('IFI11_18 Set money aside')
sns.countplot(x="IFI11_19",hue="is_female",data=df_IFI11,ax=axx[3][3]).title.set_text('IFI11_19 Make an investment')
sns.countplot(x="IFI11_20",hue="is_female",data=df_IFI11,ax=axx[3][4]).title.set_text('IFI11_20 Pay for goods or services')
sns.countplot(x="IFI11_21",hue="is_female",data=df_IFI11,ax=axx[4][0]).title.set_text('IFI11_21 Transfer money between your account')
sns.countplot(x="IFI11_22",hue="is_female",data=df_IFI11,ax=axx[4][1]).title.set_text('IFI11_22 Pay money to or receive money from your savings')
sns.countplot(x="IFI11_23",hue="is_female",data=df_IFI11,ax=axx[4][2]).title.set_text('IFI11_23 Account maintenance')

for ax in axx.flat:
    ax.set(xlabel='')

# %%
#Have you ever used a mobile money account to do the following?
MM15 =['MM15_1',	'MM15_2',	'MM15_3',	'MM15_4',	'MM15_5',	'MM15_6',	'MM15_7',	'MM15_8',	'MM15_9',	'MM15_10',	'MM15_11',	'MM15_12',\
       'MM15_13',	'MM15_14',	'MM15_15',	'MM15_16',	'MM15_17',	'MM15_18',	'MM15_19',	'MM15_20',	'MM15_21',	'MM15_22',	'MM15_23','is_female']
df_MM15 = df[MM15]
df_MM15.replace(inplace=True,to_replace=2,value=0)
MM15 = df_MM15.sum(axis=1,min_count=1)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
fig, axx =plt.subplots(figsize=(30,20),ncols=5,nrows=5)
sns.countplot(x="MM15_1",hue="is_female",data=df_MM15,ax=axx[0][0]).title.set_text('MM15_1 Deposit money')
sns.countplot(x="MM15_2",hue="is_female",data=df_MM15,ax=axx[0][1]).title.set_text('MM15_2 Withdraw money')
sns.countplot(x="MM15_3",hue="is_female",data=df_MM15,ax=axx[0][2]).title.set_text('MM15_3 Buy airtime top-ups, pay mobile phone bill')
sns.countplot(x="MM15_4",hue="is_female",data=df_MM15,ax=axx[0][3]).title.set_text('MM15_4 Pay a school fee')
sns.countplot(x="MM15_5",hue="is_female",data=df_MM15,ax=axx[0][4]).title.set_text('MM15_5 Pay a medical bill')
sns.countplot(x="MM15_6",hue="is_female",data=df_MM15,ax=axx[1][0]).title.set_text('MM15_6 Pay a utility bill')
sns.countplot(x="MM15_7",hue="is_female",data=df_MM15,ax=axx[1][1]).title.set_text('MM15_7 Pay rent')
sns.countplot(x="MM15_8",hue="is_female",data=df_MM15,ax=axx[1][2]).title.set_text('MM15_8 Pay a government bill, including tax, fine or fee')
sns.countplot(x="MM15_9",hue="is_female",data=df_MM15,ax=axx[1][3]).title.set_text('MM15_9 Send money to family')
sns.countplot(x="MM15_10",hue="is_female",data=df_MM15,ax=axx[1][4]).title.set_text('MM15_10 Receive money')
sns.countplot(x="MM15_11",hue="is_female",data=df_MM15,ax=axx[2][0]).title.set_text('MM15_11 Receive welfare')
sns.countplot(x="MM15_12",hue="is_female",data=df_MM15,ax=axx[2][1]).title.set_text('MM15_12 Receive wages')
sns.countplot(x="MM15_13",hue="is_female",data=df_MM15,ax=axx[2][2]).title.set_text('MM15_13 Pay for large acquisitions')
sns.countplot(x="MM15_14",hue="is_female",data=df_MM15,ax=axx[2][3]).title.set_text('MM15_14 Make insurance-related payments')
sns.countplot(x="MM15_15",hue="is_female",data=df_MM15,ax=axx[2][4]).title.set_text('MM15_15 Take a loan')
sns.countplot(x="MM15_16",hue="is_female",data=df_MM15,ax=axx[3][0]).title.set_text('MM15_16 Save money')
sns.countplot(x="MM15_17",hue="is_female",data=df_MM15,ax=axx[3][1]).title.set_text('MM15_17 Set aside money for pension')
sns.countplot(x="MM15_18",hue="is_female",data=df_MM15,ax=axx[3][2]).title.set_text('MM15_18 Set money aside')
sns.countplot(x="MM15_19",hue="is_female",data=df_MM15,ax=axx[3][3]).title.set_text('MM15_19 Make an investment')
sns.countplot(x="MM15_20",hue="is_female",data=df_MM15,ax=axx[3][4]).title.set_text('MM15_20 Pay for goods or services')
sns.countplot(x="MM15_21",hue="is_female",data=df_MM15,ax=axx[4][0]).title.set_text('MM15_21 Transfer money between your account')
sns.countplot(x="MM15_22",hue="is_female",data=df_MM15,ax=axx[4][1]).title.set_text('MM15_22 Pay money to or receive money from your savings')
sns.countplot(x="MM15_23",hue="is_female",data=df_MM15,ax=axx[4][2]).title.set_text('MM15_23 Account maintenance')

for ax in axx.flat:
    ax.set(xlabel='')
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
#Have you ever used your SAVINGS AND/OR LENDING GROUP account to do the following?
IFI12 =['IFI12_1',	'IFI12_2',	'IFI12_3',	'IFI12_4',	'IFI12_5',	'IFI12_6',	'IFI12_7',	'IFI12_8',	'IFI12_9',	'IFI12_10',	'IFI12_11',	'IFI12_12',\
       'IFI12_13',	'IFI12_14',	'IFI12_15',	'IFI12_16',	'IFI12_17',	'IFI12_18',	'IFI12_19',	'IFI12_20',	'IFI12_21',	'IFI12_22',	'IFI12_23','is_female']
df_IFI12 = df[IFI12]
df_IFI12.replace(inplace=True,to_replace=2,value=0)
IFI12 = df_IFI12.sum(axis=1,min_count=1)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
fig, axx =plt.subplots(figsize=(30,20),ncols=5,nrows=5)
sns.countplot(x="IFI12_1",hue="is_female",data=df_IFI12,ax=axx[0][0]).title.set_text('IFI12_1 Deposit money')
sns.countplot(x="IFI12_2",hue="is_female",data=df_IFI12,ax=axx[0][1]).title.set_text('IFI12_2 Withdraw money')
sns.countplot(x="IFI12_3",hue="is_female",data=df_IFI12,ax=axx[0][2]).title.set_text('IFI12_3 Buy airtime top-ups, pay mobile phone bill')
sns.countplot(x="IFI12_4",hue="is_female",data=df_IFI12,ax=axx[0][3]).title.set_text('IFI12_4 Pay a school fee')
sns.countplot(x="IFI12_5",hue="is_female",data=df_IFI12,ax=axx[0][4]).title.set_text('IFI12_5 Pay a medical bill')
sns.countplot(x="IFI12_6",hue="is_female",data=df_IFI12,ax=axx[1][0]).title.set_text('IFI12_6 Pay a utility bill')
sns.countplot(x="IFI12_7",hue="is_female",data=df_IFI12,ax=axx[1][1]).title.set_text('IFI12_7 Pay rent')
sns.countplot(x="IFI12_8",hue="is_female",data=df_IFI12,ax=axx[1][2]).title.set_text('IFI12_8 Pay a government bill, including tax, fine or fee')
sns.countplot(x="IFI12_9",hue="is_female",data=df_IFI12,ax=axx[1][3]).title.set_text('IFI12_9 Send money to family')
sns.countplot(x="IFI12_10",hue="is_female",data=df_IFI12,ax=axx[1][4]).title.set_text('IFI12_10 Receive money')
sns.countplot(x="IFI12_11",hue="is_female",data=df_IFI12,ax=axx[2][0]).title.set_text('IFI12_11 Receive welfare')
sns.countplot(x="IFI12_12",hue="is_female",data=df_IFI12,ax=axx[2][1]).title.set_text('IFI12_12 Receive wages')
sns.countplot(x="IFI12_13",hue="is_female",data=df_IFI12,ax=axx[2][2]).title.set_text('IFI12_13 Pay for large acquisitions')
sns.countplot(x="IFI12_14",hue="is_female",data=df_IFI12,ax=axx[2][3]).title.set_text('IFI12_14 Make insurance-related payments')
sns.countplot(x="IFI12_15",hue="is_female",data=df_IFI12,ax=axx[2][4]).title.set_text('IFI12_15 Take a loan')
sns.countplot(x="IFI12_16",hue="is_female",data=df_IFI12,ax=axx[3][0]).title.set_text('IFI12_16 Save money')
sns.countplot(x="IFI12_17",hue="is_female",data=df_IFI12,ax=axx[3][1]).title.set_text('IFI12_17 Set aside money for pension')
sns.countplot(x="IFI12_18",hue="is_female",data=df_IFI12,ax=axx[3][2]).title.set_text('IFI12_18 Set money aside')
sns.countplot(x="IFI12_19",hue="is_female",data=df_IFI12,ax=axx[3][3]).title.set_text('IFI12_19 Make an investment')
sns.countplot(x="IFI12_20",hue="is_female",data=df_IFI12,ax=axx[3][4]).title.set_text('IFI12_20 Pay for goods or services')
sns.countplot(x="IFI12_21",hue="is_female",data=df_IFI12,ax=axx[4][0]).title.set_text('IFI12_21 Transfer money between your account')
sns.countplot(x="IFI12_22",hue="is_female",data=df_IFI12,ax=axx[4][1]).title.set_text('IFI12_22 Pay money to or receive money from your savings')
sns.countplot(x="IFI12_23",hue="is_female",data=df_IFI12,ax=axx[4][2]).title.set_text('IFI12_23 Account maintenance')

for ax in axx.flat:
    ax.set(xlabel='')
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
#Do you receive the following services through any of the informal societies or group  saving schemes that you personally belong to? 
IFI20 =['IFI20_1',	'IFI20_2',	'IFI20_3',	'IFI20_4',	'IFI20_5',	'IFI20_6',	'IFI20_7',	'IFI20_8',	'IFI20_9','is_female']
df_IFI20 = df[IFI20]
df_IFI20.replace(inplace=True,to_replace=2,value=0)
IFI20 = df_IFI20.sum(axis=1,min_count=1)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Have you experienced any of the following with an informal society/group you belong to? 
IFI22 =['IFI22_1',	'IFI22_2',	'IFI22_3',	'IFI22_4',	'IFI22_5',	'IFI22_6',	'IFI22_7',	'IFI22_8',	'IFI22_9','is_female']
df_IFI22 = df[IFI22]
df_IFI22.replace(inplace=True,to_replace=2,value=0)
IFI22 = df_IFI22.sum(axis=1,min_count=1)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Have you experienced any of the following with an informal society/group you belong to? 
IFI23 =['IFI23_1',	'IFI23_2','is_female']
df_IFI23 = df[IFI23]
df_IFI23.replace(inplace=True,to_replace=2,value=0)
IFI23 = df_IFI23.sum(axis=1,min_count=1)
# Out:
# C:\Users\Kim.Vuong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Do you current have a loan with this organization? 
FB16A =['FB16A_1',	'FB16A_2',	'FB16A_3',	'FB16A_4',	'FB16A_5',	'FB16A_6',	'FB16A_7','is_female']
df_FB16A = df[FB16A]
df_FB16A.replace(inplace=True,to_replace=2,value=0)
FB16A = df_FB16A.sum(axis=1,min_count=1)
